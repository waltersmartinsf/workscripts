# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import batman
import numpy as np
from scipy import signal
from sklearn.decomposition import FastICA, PCA
from pandas import DataFrame

# %%
import scipy.io as sio
import glob

# %%
def init_plotting():
    plt.rcParams['figure.figsize'] = (14.0,8.0)
    plt.rcParams['font.size'] = 10
    #plt.rcParams['font.family'] = 'Times New Roman'
    plt.rcParams['axes.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['axes.titlesize'] = 2*plt.rcParams['font.size']
    plt.rcParams['legend.fontsize'] = 0.65*plt.rcParams['font.size']
    plt.rcParams['xtick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['ytick.labelsize'] = plt.rcParams['font.size']
    plt.rcParams['xtick.major.size'] = 3
    plt.rcParams['xtick.minor.size'] = 3
    plt.rcParams['xtick.major.width'] = 1
    plt.rcParams['xtick.minor.width'] = 1
    plt.rcParams['ytick.major.size'] = 3
    plt.rcParams['ytick.minor.size'] = 3
    plt.rcParams['ytick.major.width'] = 1
    plt.rcParams['ytick.minor.width'] = 1
    plt.rcParams['legend.frameon'] = True
    plt.rcParams['legend.loc'] = 'best'
    plt.rcParams['axes.linewidth'] = 1

init_plotting()

# %%
matlab_binaries = glob.glob('*.mat')

# %%
matlab_binaries
# Out:
# ['synth_observations_example.mat']

# %%
data = sio.loadmat('synth_observations_example.mat')

# %%
data.keys()
# Out:
# dict_keys(['Wmatrix', 'Wwasobi', '__version__', 'ISRefica', 'nonseparablecomponents', 'Norm_ISR', 'ISRwasobi', 'X', '__header__', 'Wefica', 'result', '__globals__'])

# %%
data.items()
# Out:
# dict_items([('Wmatrix', array([[ 7256.2431391 , -7266.19604094],
#        [ -131.49794035,  -124.898853  ]])), ('Wwasobi', array([[ 7256.2431391 , -7266.19604094],
#        [ -131.49794035,  -124.898853  ]])), ('__version__', '1.0'), ('ISRefica', array([[ 0.        ,  0.0132916 ],
#        [ 0.01425342,  0.        ]])), ('nonseparablecomponents', array([], shape=(0, 0), dtype=uint8)), ('Norm_ISR', array([[ 0.00357634]])), ('ISRwasobi', array([[  0.00000000e+00,   1.06210620e-03],
#        [  3.62162470e-06,   0.00000000e+00]])), ('X', array([[ 1.00029699,  1.00016831,  1.00023382, ...,  1.00007325,
#          0.9999567 ,  1.00004339],
#        [ 1.00027796,  1.00006205,  1.00007806, ...,  1.0000518 ,
#          1.00010181,  1.00005545]])), ('__header__', b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue Aug 30 11:28:47 2016'), ('Wefica', array([[  197.61334921,    58.95789739],
#        [-7255.29685858,  7268.68525969]])), ('result', array([[  -9.81758018,   -9.18248163,   -8.82342331, ...,   -9.79784117,
#          -11.0068386 ,  -10.0409682 ],
#        [-256.47056301, -256.42667517, -256.43729016, ..., -256.41289529,
#         -256.40381605, -256.40942351]])), ('__globals__', [])])

# %%
Norm = (data['ISRwasobi'].mean() + data['ISRefica'].mean()) / 2.

# %%
#plt.grid()
plt.imshow(data['ISRwasobi']/Norm)
plt.colorbar()
plt.title('WASOBI Normalized at '+str(round(Norm,5)))

# %%
# plt.grid()
plt.imshow(data['ISRefica']/Norm)
plt.colorbar()
plt.title('EFICA Normalized at '+str(round(Norm,5)))

# %%
result = data['result']

# %%
plt.plot(result[0])

# %%
plt.plot(result[1])

# %%
Sa = result[1]

# %%
W = data['Wmatrix'] #de-mixing matrix

# %%
print(W)
# Out:
# [[ 7256.2431391  -7266.19604094]
#  [ -131.49794035  -124.898853  ]]

# %%
lcsignals = np.outer(W[1],Sa).T

# %%
lcsignals = DataFrame(lcsignals)

# %%
lcsignals
# Out:
#                 0             1
# 0    33725.350797  32032.879150
# 1    33719.579636  32027.397608
# 2    33720.975485  32028.723408
# 3    33722.518276  32030.188776
# 4    33725.307796  32032.838307
# 5    33715.433182  32023.459240
# 6    33725.654614  32033.167720
# 7    33719.870059  32027.673457
# 8    33721.958019  32029.656635
# 9    33722.136593  32029.826248
# 10   33724.703199  32032.264050
# 11   33721.392140  32029.119154
# 12   33723.247838  32030.881726
# 13   33722.232329  32029.917179
# 14   33725.464703  32032.987340
# 15   33721.777581  32029.485252
# 16   33725.469856  32032.992234
# 17   33721.524113  32029.244504
# 18   33724.072110  32031.664632
# 19   33723.070853  32030.713623
# 20   33717.485301  32025.408376
# 21   33726.824307  32034.278713
# 22   33726.882895  32034.334361
# 23   33723.529912  32031.149644
# 24   33729.461146  32036.783225
# 25   33720.473540  32028.246653
# 26   33724.031444  32031.626007
# 27   33722.322809  32030.003118
# 28   33726.410497  32033.885670
# 29   33727.615042  32035.029766
# ..            ...           ...
# 970  33712.711756  32020.874386
# 971  33715.313189  32023.345269
# 972  33712.696362  32020.859764
# 973  33712.342767  32020.523914
# 974  33719.633266  32027.448547
# 975  33713.802869  32021.910743
# 976  33708.802944  32017.161734
# 977  33711.767798  32019.977800
# 978  33714.454348  32022.529528
# 979  33713.126034  32021.267874
# 980  33715.853892  32023.858838
# 981  33712.559523  32020.729793
# 982  33714.211104  32022.298491
# 983  33716.453422  32024.428280
# 984  33712.939765  32021.090952
# 985  33715.420643  32023.447330
# 986  33714.842903  32022.898583
# 987  33718.192935  32026.080497
# 988  33717.133299  32025.074038
# 989  33714.623954  32022.690622
# 990  33717.059842  32025.004268
# 991  33716.368899  32024.347999
# 992  33715.738307  32023.749052
# 993  33718.320128  32026.201308
# 994  33719.586748  32027.404363
# 995  33717.735599  32025.646112
# 996  33713.380457  32021.509529
# 997  33717.767610  32025.676517
# 998  33716.573709  32024.542531
# 999  33717.311078  32025.242896
#
# [1000 rows x 2 columns]

# %%
lcsignals = lcsignals/lcsignals.median()

# %%
plt.plot(lcsignals[1])

# %%
plt.plot(data['X'].T, label='original')
plt.plot(lcsignals[1],label='after ICA')
plt.legend()
plt.savefig('comparing_lc.pdf')
